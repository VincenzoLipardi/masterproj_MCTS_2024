# %% [markdown]
# # Quantum Circuit Design through Monte Carlo Tree Search
# In this tutorial we show the whole pipeline of the Monte Carlo Tree Search (MCTS) implemented for quantum circuit design.
#
# ## Brief intro to the task of quantum circuit design
# The goal is finding a quantum circuit that solve a certain problem.
# Let's start from the beginning.
# What is a quantum circuit?
# A quantum circuit is a model for quantum computation, similar to classical circuits, in which a computation is done on qubits (orizontal line), namely the quantum analogue of bits, through a sequence of quantum gates (boxes).
# An example of quantum circuit (random) is below.

# %%
# Import library that allow to work with quantum circuits
from qiskit import QuantumCircuit

# Initialize a quantum circuit with 4 qubits
qc = QuantumCircuit(4)
# Add a non-parameterized gate on the 0th qubit 
qc.h(0)
# Add a parameterized gate on each of the four qubits (all with a parameter fixed to 0.5)
for i in range(4):
    qc.ry(0.5, i)
print("You have built your first quantum circuit:")
qc.draw()

# If you want to print the circuit in a fancier way uncomment replace the previous line of code with the following one
# qc.draw("mpl")
# Out:
# You have built your first quantum circuit:
#         ┌───┐   ┌─────────┐
# q_0: ───┤ H ├───┤ Ry(0.5) ├
#      ┌──┴───┴──┐└─────────┘
# q_1: ┤ Ry(0.5) ├───────────
#      ├─────────┤
# q_2: ┤ Ry(0.5) ├───────────
#      ├─────────┤
# q_3: ┤ Ry(0.5) ├───────────
#      └─────────┘

# %% [markdown]
# Why are we interested in those circuits?
# It is possible to encode some problems, either classical or quantum, into the framework of quantum circuits. In this context, solving the problem means finding a suitable quantum circuit that represent in such a way the solution.
#
# How do people find the right structure of the circuit for a given problem?
# In certain domains, it is possible to exploit the structure of the original problem to guess a suitable quantum circuits. In other domains, we ha no clue and we either try (cry) with extremely computational expensive exhaustive search or with other "smarter" search techniques.
#
# What do you mean with "quantum circuit design"?
# Designing a quantum circuit means finding the ordered sequence of gates (parameterized and not-parameterized) applied to the qubits that give raise to the circuit that can solve a given problem.
# You can imagine the task of designing a quantum circuit as the quantum analogue of the design of Neural Networks. In neural networks you have to find the stucture (number of neurons, hidden layers, activation function, etc.) that allows to solve the problem after the learning of the parameters (weights). Similarly, in the quantum setting, we also have to find the structure (sequence of gates), that allows to solve the problem after the learning of the parameters (angle parameters of the parameterized gates).
# However, the search space defined by quantum circuits is extremely big (exponential in the number of qubits) and we want to find automatic and efficient way to get "good" circuits. Namely, we want a "shallow circuit" that evaluated on an objevtive function gives a value "close" to the optimum.
#
# Why do you want a shallow circuit?
# Currently available quantum computers suffer of several limitations. The most important relates to the number of qubits we dispose and the number of gates we can apply.
#
# Nice! But we have been told that we do NOT need quantum for this project. So what?
# In this project, we will provide you some problems encoded in the circuit-based quantum computing setting in a black-box form. That means, that the problems are provided as real-valued function on the domain of quantum circuits. This functions will be your objective functions and your goal is to minimize them.
# You don't have to understand what exactly those "quantum" functions do, but you only need to work with MCTS and its variants to get hopefully better results (lower values of the objective functions).

# %% [markdown]
# ## Objective functions
#
#
# Here we define an objective function to optimize. The objective function is a real-valued function defined on quantum circuits. You can find examples in the file evaluation_functions.py about quantum chemistry, systems of linear equations and combinatorial optimization (Max-Cut).
#
# Let's take a famous example from the domain of quantum chemistry. The study of molecules involves quantum phenomena and as such this fiels is considered one of the most promising application for quantum computing.
# Here we will estimate the ground state energy of the hydrogen molecule $H_2$ by using an hybrid classical-quantum algorithm, the variational quantum eigensolver.
#
# In the following we evaluate the quantum circuit created above as a solution for the ground state energy problem on $H_2$.
#
# You can change the problem as described below. The number of qubits required for each problem is in the dictionary named "N_QUBITS" in file main.py

# %%
import evaluation_functions as evf

# The quantum problems provided as black-box are in evf
problem = evf.h2    # one of the problem provided
# You can equivalently work with the other evaluation functions (pay attention to the number of qubits required, as it depends on the evaluation function):
"""
# Quantum Chemistry But on different molecules
problem = evf.lih
problem = evf.h2o
# Different systems of linear equations
problem = evf.vqls_0
problem = evf.vqls_1
# NP-Hard problem: MAX-CUT
problem = evf.max_cut

"""
cost_value = problem(qc, cost=True)

print(f"Given the quantum circuit below: \n{qc}\n the objective function returns: {cost_value}")
# Out:
# Given the quantum circuit below:
#         ┌───┐   ┌─────────┐
# q_0: ───┤ H ├───┤ Ry(0.5) ├
#      ┌──┴───┴──┐└─────────┘
# q_1: ┤ Ry(0.5) ├───────────
#      ├─────────┤
# q_2: ┤ Ry(0.5) ├───────────
#      ├─────────┤
# q_3: ┤ Ry(0.5) ├───────────
#      └─────────┘
#  the objective function returns: -0.2318460796537938

# %% [markdown]
# ## Link Quantum to Classical
# Once we have defined the problem, we can use MCTS in order to design a first guess, also known as "ansatz", for the initial quantum circuit that.
# We hope you did not get scared with this brief intro into the "quantum world". Anyways, from now on you will only work with classical techniques. Here there is the link we created between the classical and quantum "world":
# - Node: Quantum Circuit
# - Moves: apply changes to the circuit. There are 4 possible changes implemented:
#     1. Add new random gate in random position
#     2. Remove radom gate in random position
#     3. Swap a random gate with a new gate in the same position
#     4. Change the angle parameter in a parameterized gate
# - Objective function: quantum black box provided

# %% [markdown]
# ## Your MCTS baseline
# Below you will see how does your baseline work

# %%
# Number of qubits required by the problem. In the problem of estimating the ground state energy of the ydrogen we only need 4 qubits (For all the other problems we provide you of all the information)
variable_qubits = 4
ancilla_qubits = 0
# Max depth of the circuit that we want to search with the MCTS
max_depth = 10
# Computational budget we provide MCTS to explore the search space. it is equivalent to the number of new nodes evaluated
budget = 1000
# Set to false MCTS use an adaptive technique to fix the branching factor of each node. This allows to explore more the most promising nodes. Set to an integer, the branching factor will be fixed for all nodes of the tree.
branches = False

criteria = "average_value"
rollout_type = 'classic'
roll_out_steps = 2
choices = {'a': 50, 'd': 10, 's': 20, 'c': 20, 'p': 0}
epsilon = None
stop_deterministic = False
# Hyperparametrs of MCTS
ucb = 0.4
pw_C = 1
pw_alpha = 0.3

# %% [markdown]
# Below we define the root node by inizializing an empty circuit. The search starts from that node and MCTS will search for the best.

# %%
import mcts
from structure import Circuit
# Initialize the search by creating an empty circuit in the root node
root = mcts.Node(Circuit(variable_qubits=variable_qubits, ancilla_qubits=ancilla_qubits), max_depth=max_depth)
        
best_path = mcts.mcts(root, budget=budget, branches=branches, evaluation_function=problem, criteria=criteria, rollout_type=rollout_type, roll_out_steps=roll_out_steps,
                                choices=choices, epsilon=epsilon, stop_deterministic=stop_deterministic, ucb_value=ucb, pw_C=pw_C, pw_alpha=pw_alpha, verbose=True)
# Out:
# Root Node:
#  Tree depth: 0  -  Generated by Action: None  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├
#      ├───┤
# v_1: ┤ H ├
#      ├───┤
# v_2: ┤ H ├
#      ├───┤
# v_3: ┤ H ├
#      └───┘
# Epoch Counter:  0
# Node Expanded:
#  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Reward:  -0.09976599014477001
# Epoch Counter:  1
# Node Expanded:
#  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Reward:  0.04207897977473342
# Epoch Counter:  2
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.04207897977473342  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Node Expanded:
#  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌────────────┐┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├
#      ├───┤└────────────┘└─┬─┘
# v_3: ┤ H ├────────────────■──
#      └───┘
# Reward:  0.04207897977473338
# Epoch Counter:  3
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.0841579595494668  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Node Expanded:
#  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤├────────────┤
# v_3: ┤ H ├┤ Ry(2.7353) ├
#      └───┘└────────────┘
# Reward:  -0.053853985527646614
# Epoch Counter:  4
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: -0.09976599014477001  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Node Expanded:
#  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├──────────────
#      ├───┤└─┬─┘┌────────────┐
# v_3: ┤ H ├──■──┤ Rx(5.1438) ├
#      └───┘     └────────────┘
# Reward:  0.04207897977473339
# Epoch Counter:  5
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: -0.05768701037003662  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Node Expanded:
#  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 2):
#      ┌───┐
# v_0: ┤ H ├──────────
#      ├───┤
# v_1: ┤ H ├───────■──
#      ├───┤┌───┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘
# v_3: ┤ H ├──■───────
#      └───┘
# Reward:  0.1634110656609432
# Epoch Counter:  6
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 3  -  Value: 0.10572405529090659  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.1634110656609432  -  Quantum Circuit (CNOT counts)= 2):
#      ┌───┐
# v_0: ┤ H ├──────────
#      ├───┤
# v_1: ┤ H ├───────■──
#      ├───┤┌───┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘
# v_3: ┤ H ├──■───────
#      └───┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 3):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────■────■──
#      ├───┤┌───┐┌─┴─┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘└───┘
# v_3: ┤ H ├──■────────────
#      └───┘
# Reward:  0.04207897977473336
# Epoch Counter:  7
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 3  -  Value: 0.030303974021820182  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.04207897977473338  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌────────────┐┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├
#      ├───┤└────────────┘└─┬─┘
# v_3: ┤ H ├────────────────■──
#      └───┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────────────────────────────────
#      ├───┤
# v_1: ┤ H ├─────────────────────────────────
#      ├───┤┌────────────┐┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├──────────────
#      ├───┤└────────────┘└─┬─┘┌────────────┐
# v_3: ┤ H ├────────────────■──┤ Ry(5.9368) ├
#      └───┘                   └────────────┘
# Reward:  0.12448731085893837
# Epoch Counter:  8
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 4  -  Value: 0.15479128488075855  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: -0.053853985527646614  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤├────────────┤
# v_3: ┤ H ├┤ Ry(2.7353) ├
#      └───┘└────────────┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├────────────────────────────
#      ├───┤
# v_1: ┤ H ├────────────────────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├──────────────
#      ├───┤├────────────┤┌────────────┐
# v_3: ┤ H ├┤ Ry(2.7353) ├┤ Rx(2.3067) ├
#      └───┘└────────────┘└────────────┘
# Reward:  -0.0637933310221204
# Epoch Counter:  9
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 4  -  Value: 0.14780303506563996  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.04207897977473339  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├──────────────
#      ├───┤└─┬─┘┌────────────┐
# v_3: ┤ H ├──■──┤ Rx(5.1438) ├
#      └───┘     └────────────┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐┌────────────┐
# v_0: ┤ H ├┤ Rz(3.7575) ├──────────────
#      ├───┤└────────────┘
# v_1: ┤ H ├────────────────────────────
#      ├───┤    ┌───┐
# v_2: ┤ H ├────┤ X ├───────────────────
#      ├───┤    └─┬─┘     ┌────────────┐
# v_3: ┤ H ├──────■───────┤ Rx(5.1438) ├
#      └───┘              └────────────┘
# Reward:  0.05339651324591581
# Epoch Counter:  10
# Node Expanded:
#  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Reward:  0.04207897977473339
# Epoch Counter:  11
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.04207897977473339  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Node Expanded:
#  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤ ┌────────────┐
# v_1: ┤ H ├─┤ Rz(3.1131) ├
#      ├───┤ └────────────┘
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Reward:  0.042078979774733405
# Epoch Counter:  12
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.0841579595494668  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Node Expanded:
#  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤
# v_2: ┤ H ├───────────────────────────────
#      ├───┤┌─────────────┐┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Reward:  0.6239915351344149
# Epoch Counter:  13
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 3  -  Value: 0.7081494946838817  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.6239915351344149  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤
# v_2: ┤ H ├───────────────────────────────
#      ├───┤┌─────────────┐┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤ ┌────────────┐
# v_2: ┤ H ├─┤ Rx(6.2758) ├────────────────
#      ├───┤┌┴────────────┤┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Reward:  0.04319630068487608
# Epoch Counter:  14
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 4  -  Value: 0.7513457953687578  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.667187835819291  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤
# v_2: ┤ H ├───────────────────────────────
#      ├───┤┌─────────────┐┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤ ┌────────────┐
# v_2: ┤ H ├─┤ Ry(2.9859) ├────────────────
#      ├───┤┌┴────────────┤┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Reward:  0.043169902950977806
# Epoch Counter:  15
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 5  -  Value: 0.7945156983197356  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.042078979774733405  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤ ┌────────────┐
# v_1: ┤ H ├─┤ Rz(3.1131) ├
#      ├───┤ └────────────┘
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤ ┌────────────┐
# v_1: ┤ H ├─┤ Rz(3.1131) ├
#      ├───┤ ├────────────┤
# v_2: ┤ H ├─┤ Rx(3.2861) ├
#      ├───┤┌┴────────────┤
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Reward:  -0.01618157152840059
# Epoch Counter:  16
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 6  -  Value: 0.778334126791335  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 3  -  Value: 0.7103577387702688  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤
# v_2: ┤ H ├───────────────────────────────
#      ├───┤┌─────────────┐┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.04319630068487608  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤ ┌────────────┐
# v_2: ┤ H ├─┤ Rx(6.2758) ├────────────────
#      ├───┤┌┴────────────┤┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├─────────────────────────────────────────────
#      ├───┤
# v_1: ┤ H ├─────────────────────────────────────────────
#      ├───┤ ┌────────────┐
# v_2: ┤ H ├─┤ Rx(6.2758) ├──────────────────────────────
#      ├───┤┌┴────────────┤┌──────────────┐┌────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├┤ Rx(1.2355) ├
#      └───┘└─────────────┘└──────────────┘└────────────┘
# Reward:  0.0532355734493232
# Epoch Counter:  17
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 7  -  Value: 0.8315697002406581  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 4  -  Value: 0.7635933122195919  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤
# v_2: ┤ H ├───────────────────────────────
#      ├───┤┌─────────────┐┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.043169902950977806  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤ ┌────────────┐
# v_2: ┤ H ├─┤ Ry(2.9859) ├────────────────
#      ├───┤┌┴────────────┤┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤                    ┌───┐
# v_1: ┤ H ├────────────────────┤ X ├──────
#      ├───┤ ┌────────────┐     └─┬─┘
# v_2: ┤ H ├─┤ Ry(2.9859) ├───────■────────
#      ├───┤┌┴────────────┤┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Reward:  0.005690068009803206
# Epoch Counter:  18
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 8  -  Value: 0.8372597682504613  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.025897408246332815  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤ ┌────────────┐
# v_1: ┤ H ├─┤ Rz(3.1131) ├
#      ├───┤ └────────────┘
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐               ┌───┐
# v_0: ┤ H ├───────────────┤ X ├
#      ├───┤ ┌────────────┐└─┬─┘
# v_1: ┤ H ├─┤ Rz(3.1131) ├──┼──
#      ├───┤ └────────────┘  │
# v_2: ┤ H ├─────────────────┼──
#      ├───┤┌─────────────┐  │
# v_3: ┤ H ├┤ Rz(0.04731) ├──■──
#      └───┘└─────────────┘
# Reward:  0.2563661950876248
# Epoch Counter:  19
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 9  -  Value: 1.093625963338086  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 3  -  Value: 0.2822636033339576  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤ ┌────────────┐
# v_1: ┤ H ├─┤ Rz(3.1131) ├
#      ├───┤ └────────────┘
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.2563661950876248  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐               ┌───┐
# v_0: ┤ H ├───────────────┤ X ├
#      ├───┤ ┌────────────┐└─┬─┘
# v_1: ┤ H ├─┤ Rz(3.1131) ├──┼──
#      ├───┤ └────────────┘  │
# v_2: ┤ H ├─────────────────┼──
#      ├───┤┌─────────────┐  │
# v_3: ┤ H ├┤ Rz(0.04731) ├──■──
#      └───┘└─────────────┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐               ┌───┐┌────────────┐
# v_0: ┤ H ├───────────────┤ X ├┤ Rx(5.3341) ├
#      ├───┤ ┌────────────┐└─┬─┘└────────────┘
# v_1: ┤ H ├─┤ Rz(3.1131) ├──┼────────────────
#      ├───┤ └────────────┘  │
# v_2: ┤ H ├─────────────────┼────────────────
#      ├───┤┌─────────────┐  │
# v_3: ┤ H ├┤ Rz(0.04731) ├──■────────────────
#      └───┘└─────────────┘
# Reward:  0.042078979774733405
# Epoch Counter:  20
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 5  -  Value: 0.2011995483115558  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.20549004543567656  -  Quantum Circuit (CNOT counts)= 2):
#      ┌───┐
# v_0: ┤ H ├──────────
#      ├───┤
# v_1: ┤ H ├───────■──
#      ├───┤┌───┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘
# v_3: ┤ H ├──■───────
#      └───┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 3):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────■───────
#      ├───┤┌───┐┌─┴─┐┌───┐
# v_2: ┤ H ├┤ X ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘└─┬─┘
# v_3: ┤ H ├──■─────────■──
#      └───┘
# Reward:  0.04207897977473338
# Epoch Counter:  21
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 10  -  Value: 1.1357049431128194  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 5  -  Value: 0.7692833802293951  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤
# v_2: ┤ H ├───────────────────────────────
#      ├───┤┌─────────────┐┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.09643187413419928  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────────────────
#      ├───┤ ┌────────────┐
# v_2: ┤ H ├─┤ Rx(6.2758) ├────────────────
#      ├───┤┌┴────────────┤┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────────────────────
#      ├───┤ ┌────────────┐
# v_1: ┤ H ├─┤ Rx(5.4755) ├────────────────
#      ├───┤ ├────────────┤
# v_2: ┤ H ├─┤ Rx(6.2758) ├────────────────
#      ├───┤┌┴────────────┤┌──────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(0.097484) ├
#      └───┘└─────────────┘└──────────────┘
# Reward:  0.04338009818997496
# Epoch Counter:  22
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 5  -  Value: 0.09099795385863815  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.16656629063367173  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌────────────┐┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├
#      ├───┤└────────────┘└─┬─┘
# v_3: ┤ H ├────────────────■──
#      └───┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐┌─────────────┐
# v_0: ┤ H ├┤ Ry(0.50435) ├─────
#      ├───┤└─────────────┘
# v_1: ┤ H ├────────────────────
#      ├───┤ ┌────────────┐┌───┐
# v_2: ┤ H ├─┤ Rx(1.4499) ├┤ X ├
#      ├───┤ └────────────┘└─┬─┘
# v_3: ┤ H ├─────────────────■──
#      └───┘
# Reward:  0.15322695069378653
# Epoch Counter:  23
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 6  -  Value: 0.24422490455242468  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 3  -  Value: 0.31979324132745823  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌────────────┐┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├
#      ├───┤└────────────┘└─┬─┘
# v_3: ┤ H ├────────────────■──
#      └───┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.15322695069378653  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐┌─────────────┐
# v_0: ┤ H ├┤ Ry(0.50435) ├─────
#      ├───┤└─────────────┘
# v_1: ┤ H ├────────────────────
#      ├───┤ ┌────────────┐┌───┐
# v_2: ┤ H ├─┤ Rx(1.4499) ├┤ X ├
#      ├───┤ └────────────┘└─┬─┘
# v_3: ┤ H ├─────────────────■──
#      └───┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐┌─────────────┐
# v_0: ┤ H ├┤ Ry(0.50435) ├───────────────────
#      ├───┤└─────────────┘
# v_1: ┤ H ├──────────────────────────────────
#      ├───┤ ┌────────────┐┌───┐┌────────────┐
# v_2: ┤ H ├─┤ Rx(1.4499) ├┤ X ├┤ Rx(3.0261) ├
#      ├───┤ └────────────┘└─┬─┘└────────────┘
# v_3: ┤ H ├─────────────────■────────────────
#      └───┘
# Reward:  0.26076219078189494
# Epoch Counter:  24
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 7  -  Value: 0.5049870953343196  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 4  -  Value: 0.5805554321093531  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌────────────┐┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├
#      ├───┤└────────────┘└─┬─┘
# v_3: ┤ H ├────────────────■──
#      └───┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.12448731085893837  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────────────────────────────────
#      ├───┤
# v_1: ┤ H ├─────────────────────────────────
#      ├───┤┌────────────┐┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├──────────────
#      ├───┤└────────────┘└─┬─┘┌────────────┐
# v_3: ┤ H ├────────────────■──┤ Ry(5.9368) ├
#      └───┘                   └────────────┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────────────────────────────────
#      ├───┤┌────────────┐
# v_1: ┤ H ├┤ Rx(5.2058) ├───────────────────
#      ├───┤├────────────┤┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├──────────────
#      ├───┤└────────────┘└─┬─┘┌────────────┐
# v_3: ┤ H ├────────────────■──┤ Ry(5.9368) ├
#      └───┘                   └────────────┘
# Reward:  -0.045061064958827515
# Epoch Counter:  25
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 6  -  Value: 0.24327852808628916  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.0954754930206492  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├──────────────
#      ├───┤└─┬─┘┌────────────┐
# v_3: ┤ H ├──■──┤ Rx(5.1438) ├
#      └───┘     └────────────┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐┌────────────┐
# v_0: ┤ H ├┤ Ry(3.9786) ├──────────────
#      ├───┤└────────────┘
# v_1: ┤ H ├────────────────────────────
#      ├───┤    ┌───┐
# v_2: ┤ H ├────┤ X ├───────────────────
#      ├───┤    └─┬─┘     ┌────────────┐
# v_3: ┤ H ├──────■───────┤ Rx(5.1438) ├
#      └───┘              └────────────┘
# Reward:  -0.08989796592505193
# Epoch Counter:  26
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 11  -  Value: 1.1790850413027945  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Node Expanded:
#  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├─────────────────────────────
#      ├───┤
# v_1: ┤ H ├─────────────────────────────
#      ├───┤
# v_2: ┤ H ├─────────────────────────────
#      ├───┤┌─────────────┐┌────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(4.2811) ├
#      └───┘└─────────────┘└────────────┘
# Reward:  -0.16645082421760132
# Epoch Counter:  27
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 8  -  Value: 0.4599260303754921  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 5  -  Value: 0.5354943671505256  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌────────────┐┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├
#      ├───┤└────────────┘└─┬─┘
# v_3: ┤ H ├────────────────■──
#      └───┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.41398914147568144  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐┌─────────────┐
# v_0: ┤ H ├┤ Ry(0.50435) ├─────
#      ├───┤└─────────────┘
# v_1: ┤ H ├────────────────────
#      ├───┤ ┌────────────┐┌───┐
# v_2: ┤ H ├─┤ Rx(1.4499) ├┤ X ├
#      ├───┤ └────────────┘└─┬─┘
# v_3: ┤ H ├─────────────────■──
#      └───┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 2):
#      ┌───┐┌─────────────┐     ┌───┐
# v_0: ┤ H ├┤ Ry(0.50435) ├─────┤ X ├
#      ├───┤└─────────────┘     └─┬─┘
# v_1: ┤ H ├──────────────────────┼──
#      ├───┤ ┌────────────┐┌───┐  │
# v_2: ┤ H ├─┤ Rx(1.4499) ├┤ X ├──■──
#      ├───┤ └────────────┘└─┬─┘
# v_3: ┤ H ├─────────────────■───────
#      └───┘
# Reward:  0.10148531954482465
# Epoch Counter:  28
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 9  -  Value: 0.5614113499203168  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: -0.11764731654976701  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤├────────────┤
# v_3: ┤ H ├┤ Ry(2.7353) ├
#      └───┘└────────────┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_1: ┤ H ├┤ Rz(1.4725) ├
#      ├───┤├────────────┤
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤├────────────┤
# v_3: ┤ H ├┤ Ry(2.7353) ├
#      └───┘└────────────┘
# Reward:  0.07061541843632947
# Epoch Counter:  29
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 7  -  Value: 0.15338056216123724  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 3  -  Value: 0.24756902521040994  -  Quantum Circuit (CNOT counts)= 2):
#      ┌───┐
# v_0: ┤ H ├──────────
#      ├───┤
# v_1: ┤ H ├───────■──
#      ├───┤┌───┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘
# v_3: ┤ H ├──■───────
#      └───┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.04207897977473336  -  Quantum Circuit (CNOT counts)= 3):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────■────■──
#      ├───┤┌───┐┌─┴─┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘└───┘
# v_3: ┤ H ├──■────────────
#      └───┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 4):
#      ┌───┐
# v_0: ┤ H ├─────────────────■──
#      ├───┤               ┌─┴─┐
# v_1: ┤ H ├───────■────■──┤ X ├
#      ├───┤┌───┐┌─┴─┐┌─┴─┐└───┘
# v_2: ┤ H ├┤ X ├┤ X ├┤ X ├─────
#      ├───┤└─┬─┘└───┘└───┘
# v_3: ┤ H ├──■─────────────────
#      └───┘
# Reward:  0.21744333277355563
# Epoch Counter:  30
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 8  -  Value: 0.37082389493479284  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 4  -  Value: 0.46501235798396556  -  Quantum Circuit (CNOT counts)= 2):
#      ┌───┐
# v_0: ┤ H ├──────────
#      ├───┤
# v_1: ┤ H ├───────■──
#      ├───┤┌───┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘
# v_3: ┤ H ├──■───────
#      └───┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.04207897977473338  -  Quantum Circuit (CNOT counts)= 3):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────■───────
#      ├───┤┌───┐┌─┴─┐┌───┐
# v_2: ┤ H ├┤ X ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘└─┬─┘
# v_3: ┤ H ├──■─────────■──
#      └───┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 3):
#      ┌───┐
# v_0: ┤ H ├─────────────────────────────
#      ├───┤
# v_1: ┤ H ├───────■─────────────────────
#      ├───┤┌───┐┌─┴─┐┌───┐┌────────────┐
# v_2: ┤ H ├┤ X ├┤ X ├┤ X ├┤ Rx(2.3169) ├
#      ├───┤└─┬─┘└───┘└─┬─┘└────────────┘
# v_3: ┤ H ├──■─────────■────────────────
#      └───┘
# Reward:  0.04207897977473339
# Epoch Counter:  31
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 3  -  Visits: 12  -  Value: 1.0126342170851932  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: -0.16645082421760132  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├─────────────────────────────
#      ├───┤
# v_1: ┤ H ├─────────────────────────────
#      ├───┤
# v_2: ┤ H ├─────────────────────────────
#      ├───┤┌─────────────┐┌────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(4.2811) ├
#      └───┘└─────────────┘└────────────┘
# Node Expanded:
#  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├─────────────────────────────
#      ├───┤ ┌────────────┐
# v_1: ┤ H ├─┤ Rx(5.1429) ├──────────────
#      ├───┤ └────────────┘
# v_2: ┤ H ├─────────────────────────────
#      ├───┤┌─────────────┐┌────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├┤ Rx(4.2811) ├
#      └───┘└─────────────┘└────────────┘
# Reward:  0.03165055853669653
# Epoch Counter:  32
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 10  -  Value: 0.6320267683566463  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 6  -  Value: 0.6369796866953502  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├───────────────────
#      ├───┤
# v_1: ┤ H ├───────────────────
#      ├───┤┌────────────┐┌───┐
# v_2: ┤ H ├┤ Rx(1.4499) ├┤ X ├
#      ├───┤└────────────┘└─┬─┘
# v_3: ┤ H ├────────────────■──
#      └───┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 3  -  Value: 0.5154744610205061  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐┌─────────────┐
# v_0: ┤ H ├┤ Ry(0.50435) ├─────
#      ├───┤└─────────────┘
# v_1: ┤ H ├────────────────────
#      ├───┤ ┌────────────┐┌───┐
# v_2: ┤ H ├─┤ Rx(1.4499) ├┤ X ├
#      ├───┤ └────────────┘└─┬─┘
# v_3: ┤ H ├─────────────────■──
#      └───┘
# Selection:  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.26076219078189494  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐┌─────────────┐
# v_0: ┤ H ├┤ Ry(0.50435) ├───────────────────
#      ├───┤└─────────────┘
# v_1: ┤ H ├──────────────────────────────────
#      ├───┤ ┌────────────┐┌───┐┌────────────┐
# v_2: ┤ H ├─┤ Rx(1.4499) ├┤ X ├┤ Rx(3.0261) ├
#      ├───┤ └────────────┘└─┬─┘└────────────┘
# v_3: ┤ H ├─────────────────■────────────────
#      └───┘
# Node Expanded:
#  Tree depth: 5  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐┌─────────────┐┌─────────────┐
# v_0: ┤ H ├┤ Ry(0.50435) ├┤ Rx(0.22697) ├──────────────
#      ├───┤└─────────────┘└─────────────┘
# v_1: ┤ H ├────────────────────────────────────────────
#      ├───┤ ┌────────────┐     ┌───┐     ┌────────────┐
# v_2: ┤ H ├─┤ Rx(1.4499) ├─────┤ X ├─────┤ Rx(3.0261) ├
#      ├───┤ └────────────┘     └─┬─┘     └────────────┘
# v_3: ┤ H ├──────────────────────■─────────────────────
#      └───┘
# Reward:  0.09996173392042258
# Epoch Counter:  33
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 9  -  Value: 0.41290287470952625  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐
# v_0: ┤ H ├─────
#      ├───┤
# v_1: ┤ H ├─────
#      ├───┤┌───┐
# v_2: ┤ H ├┤ X ├
#      ├───┤└─┬─┘
# v_3: ┤ H ├──■──
#      └───┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 5  -  Value: 0.507091337758699  -  Quantum Circuit (CNOT counts)= 2):
#      ┌───┐
# v_0: ┤ H ├──────────
#      ├───┤
# v_1: ┤ H ├───────■──
#      ├───┤┌───┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘
# v_3: ┤ H ├──■───────
#      └───┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.259522312548289  -  Quantum Circuit (CNOT counts)= 3):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────■────■──
#      ├───┤┌───┐┌─┴─┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘└───┘
# v_3: ┤ H ├──■────────────
#      └───┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 4):
#      ┌───┐
# v_0: ┤ H ├────────────────────
#      ├───┤
# v_1: ┤ H ├───────■────■────■──
#      ├───┤┌───┐┌─┴─┐┌─┴─┐┌─┴─┐
# v_2: ┤ H ├┤ X ├┤ X ├┤ X ├┤ X ├
#      ├───┤└─┬─┘└───┘└───┘└───┘
# v_3: ┤ H ├──■─────────────────
#      └───┘
# Reward:  0.06539998141877115
# Epoch Counter:  34
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 11  -  Value: 0.7319885022770689  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤└────────────┘
# v_3: ┤ H ├──────────────
#      └───┘
# Node Expanded:
#  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├──────────────
#      ├───┤
# v_1: ┤ H ├──────────────
#      ├───┤┌────────────┐
# v_2: ┤ H ├┤ Rx(1.4499) ├
#      ├───┤├────────────┤
# v_3: ┤ H ├┤ Rx(3.2885) ├
#      └───┘└────────────┘
# Reward:  0.11803595143421394
# Epoch Counter:  35
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 3  -  Visits: 13  -  Value: 1.0442847756218898  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤
# v_1: ┤ H ├───────────────
#      ├───┤
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 2  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 4  -  Value: 0.324342583108691  -  Quantum Circuit (CNOT counts)= 0):
#      ┌───┐
# v_0: ┤ H ├───────────────
#      ├───┤ ┌────────────┐
# v_1: ┤ H ├─┤ Rz(3.1131) ├
#      ├───┤ └────────────┘
# v_2: ┤ H ├───────────────
#      ├───┤┌─────────────┐
# v_3: ┤ H ├┤ Rz(0.04731) ├
#      └───┘└─────────────┘
# Selection:  Tree depth: 3  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.2984451748623582  -  Quantum Circuit (CNOT counts)= 1):
#      ┌───┐               ┌───┐
# v_0: ┤ H ├───────────────┤ X ├
#      ├───┤ ┌────────────┐└─┬─┘
# v_1: ┤ H ├─┤ Rz(3.1131) ├──┼──
#      ├───┤ └────────────┘  │
# v_2: ┤ H ├─────────────────┼──
#      ├───┤┌─────────────┐  │
# v_3: ┤ H ├┤ Rz(0.04731) ├──■──
#      └───┘└─────────────┘
# Node Expanded:
#  Tree depth: 4  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 2):
#      ┌───┐               ┌───┐
# v_0: ┤ H ├───────────────┤ X ├──■──
#      ├───┤ ┌────────────┐└─┬─┘  │
# v_1: ┤ H ├─┤ Rz(3.1131) ├──┼────┼──
#      ├───┤ └────────────┘  │  ┌─┴─┐
# v_2: ┤ H ├─────────────────┼──┤ X ├
#      ├───┤┌─────────────┐  │  └───┘
# v_3: ┤ H ├┤ Rz(0.04731) ├──■───────
#      └───┘└─────────────┘
# Reward:  0.04207897977473342
# Epoch Counter:  36
# Selection:  Tree depth: 1  -  Generated by Action: a  -  Number of Children: 3  -  Visits: 12  -  Value: 0.8500244537112829  -  Quantum Circuit (CNOT counts)= 0):
# ...
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐├────────────┤└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├┤ Rx(1.8011) ├─────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘└────────────┘                             »
# v_2: ┤ Rx(0.14619) ├─────────────────────■────────────────────────────────────»
#      └┬────────────┤┌─────────────┐    ┌─┴─┐     ┌────────────┐┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐
# «v_0: ┤ Ry(0.40399) ├
# «     └─────────────┘
# «v_1: ───────────────
# «
# «v_2: ───────────────
# «      ┌────────────┐
# «v_3: ─┤ Rx(1.3085) ├
# «      └────────────┘
# Selection:  Tree depth: 32  -  Generated by Action: d  -  Number of Children: 0  -  Visits: 1  -  Value: 0.4533578571661556  -  Quantum Circuit (CNOT counts)= 1):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐├────────────┤└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├┤ Rx(1.8011) ├─────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘└────────────┘                             »
# v_2: ┤ Rx(0.14619) ├─────────────────────■────────────────────────────────────»
#      └┬────────────┤┌─────────────┐    ┌─┴─┐     ┌────────────┐┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐
# «v_0: ┤ Ry(0.40399) ├
# «     └─────────────┘
# «v_1: ───────────────
# «
# «v_2: ───────────────
# «
# «v_3: ───────────────
# «
# Node Expanded:
#  Tree depth: 33  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐├────────────┤└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├┤ Rx(1.8011) ├─────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘└────────────┘┌────────────┐               »
# v_2: ┤ Rx(0.14619) ├─────────────────────■───────┤ Ry(1.0729) ├───────────────»
#      └┬────────────┤┌─────────────┐    ┌─┴─┐     ├────────────┤┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐
# «v_0: ┤ Ry(0.40399) ├
# «     └─────────────┘
# «v_1: ───────────────
# «
# «v_2: ───────────────
# «
# «v_3: ───────────────
# «
# Reward:  -0.03432268897555085
# Epoch Counter:  997
# Selection:  Tree depth: 31  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 4  -  Value: 0.8293832912860541  -  Quantum Circuit (CNOT counts)= 1):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐├────────────┤└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├┤ Rx(1.8011) ├─────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘└────────────┘                             »
# v_2: ┤ Rx(0.14619) ├─────────────────────■────────────────────────────────────»
#      └┬────────────┤┌─────────────┐    ┌─┴─┐     ┌────────────┐┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐
# «v_0: ┤ Ry(0.40399) ├
# «     └─────────────┘
# «v_1: ───────────────
# «
# «v_2: ───────────────
# «      ┌────────────┐
# «v_3: ─┤ Rx(1.3085) ├
# «      └────────────┘
# Selection:  Tree depth: 32  -  Generated by Action: d  -  Number of Children: 1  -  Visits: 2  -  Value: 0.41903516819060477  -  Quantum Circuit (CNOT counts)= 1):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐├────────────┤└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├┤ Rx(1.8011) ├─────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘└────────────┘                             »
# v_2: ┤ Rx(0.14619) ├─────────────────────■────────────────────────────────────»
#      └┬────────────┤┌─────────────┐    ┌─┴─┐     ┌────────────┐┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐
# «v_0: ┤ Ry(0.40399) ├
# «     └─────────────┘
# «v_1: ───────────────
# «
# «v_2: ───────────────
# «
# «v_3: ───────────────
# «
# Node Expanded:
#  Tree depth: 33  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐├────────────┤└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├┤ Rx(1.8011) ├─────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘└────────────┘                             »
# v_2: ┤ Rx(0.14619) ├─────────────────────■────────────────────────────────────»
#      └┬────────────┤┌─────────────┐    ┌─┴─┐     ┌────────────┐┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐
# «v_0: ┤ Ry(0.40399) ├
# «     └─────────────┘
# «v_1: ───────────────
# «
# «v_2: ───────────────
# «     ┌─────────────┐
# «v_3: ┤ Rx(0.58206) ├
# «     └─────────────┘
# Reward:  0.20819217942655568
# Epoch Counter:  998
# Selection:  Tree depth: 31  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 9  -  Value: 2.8719468555518914  -  Quantum Circuit (CNOT counts)= 1):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐└────────────┘└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├───────────────────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘                                           »
# v_2: ┤ Rx(0.14619) ├─────────────────────■────────────────────────────────────»
#      └┬────────────┤┌─────────────┐    ┌─┴─┐     ┌────────────┐┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐┌────────────┐
# «v_0: ┤ Ry(0.40399) ├┤ Ry(2.4891) ├
# «     └─────────────┘└────────────┘
# «v_1: ─────────────────────────────
# «
# «v_2: ─────────────────────────────
# «      ┌────────────┐
# «v_3: ─┤ Rx(1.3085) ├──────────────
# «      └────────────┘
# Selection:  Tree depth: 32  -  Generated by Action: s  -  Number of Children: 2  -  Visits: 5  -  Value: 1.732305584206808  -  Quantum Circuit (CNOT counts)= 1):
#      ┌─────────────┐ ┌────────────┐┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rx(2.5444) ├┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├────────────┤└────────────┘└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├───────────────────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘                                           »
# v_2: ┤ Rx(0.14619) ├─────────────────────■────────────────────────────────────»
#      └┬────────────┤┌─────────────┐    ┌─┴─┐     ┌────────────┐┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐┌────────────┐
# «v_0: ┤ Ry(0.40399) ├┤ Ry(2.4891) ├
# «     └─────────────┘└────────────┘
# «v_1: ─────────────────────────────
# «
# «v_2: ─────────────────────────────
# «      ┌────────────┐
# «v_3: ─┤ Rx(1.3085) ├──────────────
# «      └────────────┘
# Selection:  Tree depth: 33  -  Generated by Action: a  -  Number of Children: 1  -  Visits: 2  -  Value: 0.9550874423203966  -  Quantum Circuit (CNOT counts)= 1):
#      ┌─────────────┐ ┌────────────┐┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rx(2.5444) ├┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├────────────┤└────────────┘└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├───────────────────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘                                           »
# v_2: ┤ Rx(0.14619) ├─────────────────────■────────────────────────────────────»
#      └┬────────────┤┌─────────────┐    ┌─┴─┐     ┌────────────┐┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐┌────────────┐
# «v_0: ┤ Ry(0.40399) ├┤ Ry(2.4891) ├
# «     └─────────────┘└────────────┘
# «v_1: ─────────────────────────────
# «
# «v_2: ─────────────────────────────
# «      ┌────────────┐┌────────────┐
# «v_3: ─┤ Rx(1.3085) ├┤ Rz(1.7329) ├
# «      └────────────┘└────────────┘
# Node Expanded:
#  Tree depth: 34  -  Generated by Action: s  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 1):
#      ┌─────────────┐ ┌────────────┐┌────────────┐┌────────────┐ ┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rx(2.5444) ├┤ Rz(1.6366) ├┤ Rx(3.2975) ├─┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├────────────┤└────────────┘└────────────┘ └───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├───────────────────────────────────────────»
#       ┌───┴───┴───┐  └────────────┘                                           »
# v_2: ─┤ Ry(1.473) ├──────────────────────■────────────────────────────────────»
#       ├───────────┴┐┌─────────────┐    ┌─┴─┐     ┌────────────┐┌─────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├────┤ X ├─────┤ Rx(5.5485) ├┤ Ry(0.86532) ├»
#       └────────────┘└─────────────┘    └───┘     └────────────┘└─────────────┘»
# «     ┌─────────────┐┌────────────┐
# «v_0: ┤ Ry(0.40399) ├┤ Ry(2.4891) ├
# «     └─────────────┘└────────────┘
# «v_1: ─────────────────────────────
# «
# «v_2: ─────────────────────────────
# «      ┌────────────┐┌────────────┐
# «v_3: ─┤ Rx(1.3085) ├┤ Rz(1.7329) ├
# «      └────────────┘└────────────┘
# Reward:  0.34059442467905066
# Epoch Counter:  999
# Selection:  Tree depth: 31  -  Generated by Action: d  -  Number of Children: 2  -  Visits: 10  -  Value: 3.2456390859770377  -  Quantum Circuit (CNOT counts)= 0):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐ ┌────────────┐┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├─┤ Rx(3.2975) ├┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐└────────────┘ └────────────┘└───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├───────────────────────────────────────────»
#      ┌────┴───┴────┐ └────────────┘                                           »
# v_2: ┤ Rx(0.14619) ├──────────────────────────────────────────────────────────»
#      └┬────────────┤┌─────────────┐┌────────────┐┌─────────────┐┌────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├┤ Rx(5.5485) ├┤ Ry(0.86532) ├┤ Rx(1.3085) ├»
#       └────────────┘└─────────────┘└────────────┘└─────────────┘└────────────┘»
# «     ┌─────────────┐
# «v_0: ┤ Ry(0.40399) ├
# «     └─────────────┘
# «v_1: ───────────────
# «
# «v_2: ───────────────
# «
# «v_3: ───────────────
# «
# Selection:  Tree depth: 32  -  Generated by Action: a  -  Number of Children: 2  -  Visits: 3  -  Value: 0.96493091721548  -  Quantum Circuit (CNOT counts)= 0):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐ ┌────────────┐┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├─┤ Rx(3.2975) ├┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐└────────────┘ └────────────┘└───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├───────────────────────────────────────────»
#      ┌────┴───┴────┐ ├────────────┤                                           »
# v_2: ┤ Rx(0.14619) ├─┤ Ry(3.7112) ├───────────────────────────────────────────»
#      └┬────────────┤┌┴────────────┤┌────────────┐┌─────────────┐┌────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├┤ Rx(5.5485) ├┤ Ry(0.86532) ├┤ Rx(1.3085) ├»
#       └────────────┘└─────────────┘└────────────┘└─────────────┘└────────────┘»
# «     ┌─────────────┐
# «v_0: ┤ Ry(0.40399) ├
# «     └─────────────┘
# «v_1: ───────────────
# «
# «v_2: ───────────────
# «
# «v_3: ───────────────
# «
# Selection:  Tree depth: 33  -  Generated by Action: a  -  Number of Children: 0  -  Visits: 1  -  Value: 0.35233540227628934  -  Quantum Circuit (CNOT counts)= 0):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐ ┌────────────┐┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├─┤ Rx(3.2975) ├┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐└────────────┘ └────────────┘└───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├───────────────────────────────────────────»
#      ┌────┴───┴────┐ ├────────────┤                                           »
# v_2: ┤ Rx(0.14619) ├─┤ Ry(3.7112) ├───────────────────────────────────────────»
#      └┬────────────┤┌┴────────────┤┌────────────┐┌─────────────┐┌────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├┤ Rx(5.5485) ├┤ Ry(0.86532) ├┤ Rx(1.3085) ├»
#       └────────────┘└─────────────┘└────────────┘└─────────────┘└────────────┘»
# «     ┌─────────────┐┌────────────┐
# «v_0: ┤ Ry(0.40399) ├┤ Rx(4.6933) ├
# «     └─────────────┘└────────────┘
# «v_1: ─────────────────────────────
# «
# «v_2: ─────────────────────────────
# «
# «v_3: ─────────────────────────────
# «
# Node Expanded:
#  Tree depth: 34  -  Generated by Action: d  -  Number of Children: 0  -  Visits: 0  -  Value: 0  -  Quantum Circuit (CNOT counts)= 0):
#      ┌─────────────┐ ┌───────────┐ ┌────────────┐ ┌────────────┐┌───────────┐ »
# v_0: ┤ Rx(0.69623) ├─┤ Rz(4.747) ├─┤ Rz(1.6366) ├─┤ Rx(3.2975) ├┤ Rz(2.396) ├─»
#      └────┬───┬────┘ ├───────────┴┐└────────────┘ └────────────┘└───────────┘ »
# v_1: ─────┤ H ├──────┤ Ry(0.8973) ├───────────────────────────────────────────»
#       ┌───┴───┴────┐ └────────────┘                                           »
# v_2: ─┤ Ry(3.7112) ├──────────────────────────────────────────────────────────»
#       ├────────────┤┌─────────────┐┌────────────┐┌─────────────┐┌────────────┐»
# v_3: ─┤ Rz(4.0838) ├┤ Rz(0.83857) ├┤ Rx(5.5485) ├┤ Ry(0.86532) ├┤ Rx(1.3085) ├»
#       └────────────┘└─────────────┘└────────────┘└─────────────┘└────────────┘»
# «     ┌─────────────┐┌────────────┐
# «v_0: ┤ Ry(0.40399) ├┤ Rx(4.6933) ├
# «     └─────────────┘└────────────┘
# «v_1: ─────────────────────────────
# «
# «v_2: ─────────────────────────────
# «
# «v_3: ─────────────────────────────
# «
# Reward:  0.4111295483428914

# %% [markdown]
# Finally it outputs the path that creates the best circuit, starting from the root to the leaf. In the following we print the values of the objective function evaluated on the quantum circuits designed along the best path. Note that, in this formulation, a children node is not necessarily better than the parent.
# Remember that this is a minimization problem and the lower the objective value the better the node

# %%
quantum_circuit_path = best_path['qc']
cost = []
for i in range(len(quantum_circuit_path)):
    cost.append(problem(quantum_circuit_path[i], cost=True))
    print("Node at depth tree: ", i, "number of children: ", best_path["children"][i])
    print("Objective value: ", cost[i])
    print("Cumulative Reward: ", best_path["value"][i])
    print("Average Reward: ", best_path["value"][i]/best_path["visits"][i], "\n")
# Out:
# Node at depth tree:  0 number of children:  4
# Objective value:  -0.04207897977473338
# Cumulative Reward:  298.74112765912867
# Average Reward:  0.2984426849741545
#
# Node at depth tree:  1 number of children:  4
# Objective value:  -0.04207897977473342
# Cumulative Reward:  296.1985787039216
# Average Reward:  0.307898730461457
#
# Node at depth tree:  2 number of children:  4
# Objective value:  -0.0745148489402877
# Cumulative Reward:  294.39105732541435
# Average Reward:  0.31895022462125067
#
# Node at depth tree:  3 number of children:  4
# Objective value:  -0.0745148489402877
# Cumulative Reward:  294.17250816333933
# Average Reward:  0.3305309080486959
#
# Node at depth tree:  4 number of children:  4
# Objective value:  -0.05357222028567636
# Cumulative Reward:  292.828539981584
# Average Reward:  0.34169024501935125
#
# Node at depth tree:  5 number of children:  4
# Objective value:  -0.05357222028567636
# Cumulative Reward:  290.11200732585536
# Average Reward:  0.35379513088518943
#
# Node at depth tree:  6 number of children:  4
# Objective value:  -0.28482178217269083
# Cumulative Reward:  287.7317467576053
# Average Reward:  0.36375694912465906
#
# Node at depth tree:  7 number of children:  4
# Objective value:  -0.49556653307845533
# Cumulative Reward:  279.48014901627903
# Average Reward:  0.3716491343301583
#
# Node at depth tree:  8 number of children:  4
# Objective value:  -0.6776117013745513
# Cumulative Reward:  267.4519967259693
# Average Reward:  0.3751079897979934
#
# Node at depth tree:  9 number of children:  2
# Objective value:  -0.6776117013745513
# Cumulative Reward:  5.007508414192747
# Average Reward:  0.45522803765388614
#
# Node at depth tree:  10 number of children:  2
# Objective value:  -0.6761125826892237
# Cumulative Reward:  3.2902222395349217
# Average Reward:  0.4700317485049888
#
# Node at depth tree:  11 number of children:  2
# Objective value:  -0.3707536290793141
# Cumulative Reward:  2.015684733772857
# Average Reward:  0.5039211834432142
#
# Node at depth tree:  12 number of children:  1
# Objective value:  -0.5664201130302147
# Cumulative Reward:  1.041714739353333
# Average Reward:  0.5208573696766665

# %% [markdown]
# At this poit we selct the ansatz as the best quantum circuit found in the path.

# %%
ansatz = quantum_circuit_path[cost.index(min(cost))]
print("Selected Ansatz: \n", ansatz)
# Out:
# Selected Ansatz:
#            ┌───┐      ┌────────────┐┌────────────┐
# v_0: ─────┤ H ├──────┤ Rz(4.4867) ├┤ Rz(1.4439) ├
#           ├───┤     ┌┴────────────┤└────────────┘
# v_1: ─────┤ H ├─────┤ Ry(0.77676) ├──────────────
#      ┌────┴───┴────┐└─────────────┘
# v_2: ┤ Rx(0.14619) ├─────────────────────────────
#      └─┬──────────┬┘┌─────────────┐
# v_3: ──┤ Rz(3.98) ├─┤ Rz(0.83857) ├──────────────
#        └──────────┘ └─────────────┘

# %% [markdown]
# ## Parameter Optimization
# Once we designed the structure of our quantum circuit we optimize the parameters through a classical gradient-based optimizer. Here we chose the ADAM Optimizer

# %%
problem(quantum_circuit=ansatz, gradient=True)
# Out:
# Step = 0,  Energy = -0.68118321 Ha
# Step = 2,  Energy = -0.68817643 Ha
# Step = 4,  Energy = -0.69496031 Ha
# Step = 6,  Energy = -0.70152488 Ha
# Step = 8,  Energy = -0.70786260 Ha
# Step = 10,  Energy = -0.71396928 Ha
# Step = 12,  Energy = -0.71984486 Ha
# Step = 14,  Energy = -0.72549386 Ha
# Step = 16,  Energy = -0.73092513 Ha
# Step = 18,  Energy = -0.73615051 Ha
# Step = 20,  Energy = -0.74118248 Ha
# Step = 22,  Energy = -0.74603146 Ha
# Step = 24,  Energy = -0.75070373 Ha
# Step = 26,  Energy = -0.75520087 Ha
# Step = 28,  Energy = -0.75952059 Ha
# Step = 30,  Energy = -0.76365842 Ha
# Step = 32,  Energy = -0.76760964 Ha
# Step = 34,  Energy = -0.77137086 Ha
# Step = 36,  Energy = -0.77494103 Ha
# Step = 38,  Energy = -0.77832177 Ha
# Step = 40,  Energy = -0.78151711 Ha
# Step = 42,  Energy = -0.78453271 Ha
# Step = 44,  Energy = -0.78737491 Ha
# Step = 46,  Energy = -0.79004984 Ha
# Step = 48,  Energy = -0.79256296 Ha
# Step = 50,  Energy = -0.79491900 Ha
# Step = 52,  Energy = -0.79712224 Ha
# Step = 54,  Energy = -0.79917698 Ha
# Step = 56,  Energy = -0.80108797 Ha
# Step = 58,  Energy = -0.80286063 Ha
# Step = 60,  Energy = -0.80450097 Ha
# Step = 62,  Energy = -0.80601542 Ha
# Step = 64,  Energy = -0.80741052 Ha
# Step = 66,  Energy = -0.80869268 Ha
# Step = 68,  Energy = -0.80986800 Ha
# Step = 70,  Energy = -0.81094239 Ha
# Step = 72,  Energy = -0.81192155 Ha
# Step = 74,  Energy = -0.81281117 Ha
# Step = 76,  Energy = -0.81361692 Ha
# Step = 78,  Energy = -0.81434449 Ha
# Step = 80,  Energy = -0.81499945 Ha
# Step = 82,  Energy = -0.81558724 Ha
# Step = 84,  Energy = -0.81611304 Ha
# Step = 86,  Energy = -0.81658178 Ha
# Step = 88,  Energy = -0.81699812 Ha
# Step = 90,  Energy = -0.81736652 Ha
# Step = 92,  Energy = -0.81769123 Ha
# Step = 94,  Energy = -0.81797629 Ha
# Step = 96,  Energy = -0.81822555 Ha
# Step = 98,  Energy = -0.81844259 Ha
# Step = 100,  Energy = -0.81863076 Ha
# Step = 102,  Energy = -0.81879315 Ha
# Step = 104,  Energy = -0.81893262 Ha
# Step = 106,  Energy = -0.81905180 Ha
# Step = 108,  Energy = -0.81915309 Ha
# Step = 110,  Energy = -0.81923871 Ha
# Step = 112,  Energy = -0.81931068 Ha
# Step = 114,  Energy = -0.81937080 Ha
# Step = 116,  Energy = -0.81942071 Ha
# Step = 118,  Energy = -0.81946186 Ha
# Step = 120,  Energy = -0.81949553 Ha
# Step = 122,  Energy = -0.81952287 Ha
# Step = 124,  Energy = -0.81954487 Ha
# Step = 126,  Energy = -0.81956243 Ha
# Step = 128,  Energy = -0.81957630 Ha
# Step = 130,  Energy = -0.81958713 Ha
# Step = 132,  Energy = -0.81959549 Ha
# Step = 134,  Energy = -0.81960186 Ha
# Step = 136,  Energy = -0.81960663 Ha
# Step = 138,  Energy = -0.81961013 Ha
# Step = 140,  Energy = -0.81961266 Ha
# Step = 142,  Energy = -0.81961443 Ha
# Step = 144,  Energy = -0.81961564 Ha
# Step = 146,  Energy = -0.81961642 Ha
# Step = 148,  Energy = -0.81961689 Ha
# Step = 150,  Energy = -0.81961715 Ha
# Step = 152,  Energy = -0.81961727 Ha
# Step = 154,  Energy = -0.81961730 Ha
# Landscape is flat
# [array(-0.6776117),
#  array(-0.68118321),
#  array(-0.68470528),
#  array(-0.68817643),
#  array(-0.69159521),
#  array(-0.69496031),
#  array(-0.69827055),
#  array(-0.70152488),
#  array(-0.70472244),
#  array(-0.7078626),
#  array(-0.71094493),
#  array(-0.71396928),
#  array(-0.71693579),
#  array(-0.71984486),
#  array(-0.72269722),
#  array(-0.72549386),
#  array(-0.72823602),
#  array(-0.73092513),
#  array(-0.73356276),
#  array(-0.73615051),
#  array(-0.73868994),
#  array(-0.74118248),
#  array(-0.74362934),
#  array(-0.74603146),
#  array(-0.74838947),
#  array(-0.75070373),
#  array(-0.75297426),
#  array(-0.75520087),
#  array(-0.75738316),
#  array(-0.75952059),
#  array(-0.76161255),
#  array(-0.76365842),
#  array(-0.76565762),
#  array(-0.76760964),
#  array(-0.76951413),
#  array(-0.77137086),
#  array(-0.77317979),
#  array(-0.77494103),
#  array(-0.77665487),
#  array(-0.77832177),
#  array(-0.77994228),
#  array(-0.78151711),
#  array(-0.78304698),
#  array(-0.78453271),
#  array(-0.78597509),
#  array(-0.78737491),
#  array(-0.78873292),
#  array(-0.79004984),
#  array(-0.79132632),
#  array(-0.79256296),
#  array(-0.79376035),
#  array(-0.794919),
#  array(-0.79603946),
#  array(-0.79712224),
#  array(-0.79816788),
#  array(-0.79917698),
#  array(-0.80015012),
#  array(-0.80108797),
#  array(-0.80199123),
#  array(-0.80286063),
#  array(-0.80369694),
#  array(-0.80450097),
#  array(-0.80527352),
#  array(-0.80601542),
#  array(-0.80672749),
#  array(-0.80741052),
#  array(-0.80806533),
#  array(-0.80869268),
#  array(-0.80929332),
#  array(-0.809868),
#  array(-0.81041745),
#  array(-0.81094239),
#  array(-0.81144352),
#  array(-0.81192155),
#  array(-0.8123772),
#  array(-0.81281117),
#  array(-0.81322418),
#  array(-0.81361692),
#  array(-0.81399013),
#  array(-0.81434449),
#  array(-0.8146807),
#  array(-0.81499945),
#  array(-0.81530141),
#  array(-0.81558724),
#  array(-0.81585758),
#  array(-0.81611304),
#  array(-0.81635425),
#  array(-0.81658178),
#  array(-0.81679622),
#  array(-0.81699812),
#  array(-0.81718805),
#  array(-0.81736652),
#  array(-0.81753408),
#  array(-0.81769123),
#  array(-0.81783847),
#  array(-0.81797629),
#  array(-0.81810517),
#  array(-0.81822555),
#  array(-0.81833788),
#  array(-0.81844259),
#  array(-0.81854008),
#  array(-0.81863076),
#  array(-0.81871499),
#  array(-0.81879315),
#  array(-0.81886558),
#  array(-0.81893262),
#  array(-0.81899459),
#  array(-0.8190518),
#  array(-0.81910453),
#  array(-0.81915309),
#  array(-0.81919773),
#  array(-0.81923871),
#  array(-0.81927628),
#  array(-0.81931068),
#  array(-0.81934211),
#  array(-0.8193708),
#  array(-0.81939694),
#  array(-0.81942071),
#  array(-0.8194423),
#  array(-0.81946186),
#  array(-0.81947955),
#  array(-0.81949553),
#  array(-0.81950992),
#  array(-0.81952287),
#  array(-0.81953448),
#  array(-0.81954487),
#  array(-0.81955416),
#  array(-0.81956243),
#  array(-0.81956978),
#  array(-0.8195763),
#  array(-0.81958206),
#  array(-0.81958713),
#  array(-0.81959159),
#  array(-0.81959549),
#  array(-0.8195989),
#  array(-0.81960186),
#  array(-0.81960442),
#  array(-0.81960663),
#  array(-0.81960852),
#  array(-0.81961013),
#  array(-0.81961151),
#  array(-0.81961266),
#  array(-0.81961363),
#  array(-0.81961443),
#  array(-0.8196151),
#  array(-0.81961564),
#  array(-0.81961607),
#  array(-0.81961642),
#  array(-0.81961669),
#  array(-0.81961689),
#  array(-0.81961704),
#  array(-0.81961715),
#  array(-0.81961723),
#  array(-0.81961727),
#  array(-0.81961729),
#  array(-0.8196173)]
